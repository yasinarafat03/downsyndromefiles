# %%
import cv2
import os

def convert_to_grayscale(input_dir, output_dir):
    # Create the output directory if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Iterate through the images in the input directory
    for filename in os.listdir(input_dir):
        if filename.endswith(('.png', '.jpg', '.jpeg')):  # Add more image formats if needed
            # Read the image
            image_path = os.path.join(input_dir, filename)
            image = cv2.imread(image_path)

            # Check if the image was loaded successfully
            if image is None:
                print(f"Error loading image: {filename}")
                continue

            # Convert the image to grayscale
            grayscale_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

            # Save the grayscale image to the output directory
            output_path = os.path.join(output_dir, filename)
            cv2.imwrite(output_path, grayscale_image)

            print(f"Processed {filename} and saved to {output_dir}")

# Usage example
input_directory = '/kaggle/input/aug-down/augmented_images'
output_directory = '/kaggle/working/G_down'
convert_to_grayscale(input_directory, output_directory)
# Out:
# Processed aug_0_9187.jpeg and saved to /kaggle/working/G_down
# Processed aug_0_8525.jpeg and saved to /kaggle/working/G_down
# Processed aug_0_3462.jpeg and saved to /kaggle/working/G_down
# Processed aug_0_1131.jpeg and saved to /kaggle/working/G_down
# Processed aug_0_9620.jpeg and saved to /kaggle/working/G_down
# Processed aug_0_825.jpeg and saved to /kaggle/working/G_down
# Processed aug_0_6253.jpeg and saved to /kaggle/working/G_down
# Processed aug_0_2794.jpeg and saved to /kaggle/working/G_down
# Processed aug_0_1531.jpeg and saved to /kaggle/working/G_down
# Processed aug_0_1276.jpeg and saved to /kaggle/working/G_down
# Processed aug_0_9320.jpeg and saved to /kaggle/working/G_down
# Processed aug_0_1462.jpeg and saved to /kaggle/working/G_down
# Processed aug_0_8901.jpeg and saved to /kaggle/working/G_down
# Processed aug_0_4076.jpeg and saved to /kaggle/working/G_down
# Processed aug_0_6290.jpeg and saved to /kaggle/working/G_down
# ...

# %%
import cv2
import os

def convert_to_grayscale(input_dir, output_dir):
    # Create the output directory if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Iterate through the images in the input directory
    for filename in os.listdir(input_dir):
        if filename.endswith(('.png', '.jpg', '.jpeg')):  # Add more image formats if needed
            # Read the image
            image_path = os.path.join(input_dir, filename)
            image = cv2.imread(image_path)

            # Check if the image was loaded successfully
            if image is None:
                print(f"Error loading image: {filename}")
                continue

            # Convert the image to grayscale
            grayscale_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

            # Save the grayscale image to the output directory
            output_path = os.path.join(output_dir, filename)
            cv2.imwrite(output_path, grayscale_image)

            print(f"Processed {filename} and saved to {output_dir}")

# Usage example
input_directory = '/kaggle/input/aug-norm/augmented_images'
output_directory = '/kaggle/working/G_healthy'
convert_to_grayscale(input_directory, output_directory)
# Out:
# Processed aug_0_8525.jpeg and saved to /kaggle/working/G_healthy
# Processed aug_0_3462.jpeg and saved to /kaggle/working/G_healthy
# Processed aug_0_9620.jpeg and saved to /kaggle/working/G_healthy
# Processed aug_0_1402.jpeg and saved to /kaggle/working/G_healthy
# Processed aug_0_1531.jpeg and saved to /kaggle/working/G_healthy
# Processed aug_0_2122.jpeg and saved to /kaggle/working/G_healthy
# Processed aug_0_2724.jpeg and saved to /kaggle/working/G_healthy
# Processed aug_0_2549.jpeg and saved to /kaggle/working/G_healthy
# Processed aug_0_9619.jpeg and saved to /kaggle/working/G_healthy
# Processed aug_0_808.jpeg and saved to /kaggle/working/G_healthy
# Processed aug_0_1462.jpeg and saved to /kaggle/working/G_healthy
# Processed aug_0_930.jpeg and saved to /kaggle/working/G_healthy
# Processed aug_0_4076.jpeg and saved to /kaggle/working/G_healthy
# Processed aug_0_7463.jpeg and saved to /kaggle/working/G_healthy
# ...
